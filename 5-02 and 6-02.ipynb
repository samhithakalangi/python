# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
cars=pd.read_csv(r"C:\Users\samhi\Downloads\Cars.csv")

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.shape
# Out:
# (81, 5)

# %% [markdown]
# # EDA

# %% [raw]
# distplot
# boxplot
# scatterplot

# %%
sns.distplot(x=cars['HP'])
plt.show()

# %%
sns.distplot(x=cars['MPG'])
plt.show()

# %%
sns.distplot(x=cars['VOL'])
plt.show()

# %%
sns.distplot(x=cars['SP'])
plt.show()

# %%
sns.distplot(x=cars['WT'])
plt.title("Distribution of weight of vhicles in thousand pounds")
plt.xlabel("weight in thousand pounds")
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.show()

# %%
sns.boxplot(x=cars['WT'])
plt.show()

# %%
from seaborn import scatterplot                 # scatter plot used to find relation between two variables of a datset
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
scatterplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %% [markdown]
# # correlation matrix

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True) # more than 0.85 -strong relation (feature to feature)(multicollinearity)
# Out:
# <Axes: >

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
scatterplot(x=cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>
